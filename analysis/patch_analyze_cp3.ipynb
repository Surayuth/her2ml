# %%
import numpy as np
import polars as pl
from pathlib import Path
from utils import plot_utils, plot_utils_case
import matplotlib.pyplot as plt
from scipy.stats import bootstrap
from glob import glob
import os
from tqdm import tqdm
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'

# %%
# metric:
# the result (experiments) should be done for each alpha
# patch-level
# - empirical coverage (misconverage rate could be obtained from 1 - empirical coverage)
#   - total
#   - only for ihc_score 0,1,2-,2+,3+
#   - only for label 0, 1
# - average set size
#   - total
#   - only for ihc_score 0,1,2-,2+,3+
#   - only for label 0, 1
# - accuracy/precision/recall/f1 for confident predictions only
# - ambiguity rate (size = 2)
#   - total
#   - only for ihc_score 0,1,2-,2+,3+
#   - only for label 0, 1

# case-level
# precision/recall/f1
# ambiguity rate (for case)

# %%
root = "../results_cp/orig_feat_level_16_white_balance_False_scale_0.25_trial_100_n_est_200_model_rf_alpha_min_0.02_alpha_max_0.2_step_alpha_0.02_dryrun_ Falsealpha0alpha1"
root = Path(root)
cv = 4
r_min = 0
r_max = 100
#alphas = [0.025, 0.050, 0.075, 0.1, 0.125, 0.150, 0.175, 0.2]
alphas = np.arange(0.02, 0.2+0.02, 0.02)

# %%
# renaming steps
def rename(src):
    last_part = src.split("/")[-1]
    splits = last_part.split("_")
    splits[3] = str(round(float(splits[3]), 2))
    splits[5] = str(round(float(splits[5]), 2))
    new_last_part = "_".join(splits)
    new_path = Path(src).parent / new_last_part
    return new_path

paths = glob(os.path.join(root, "*", "*"))
for i in tqdm(range(len(paths))):
    tmp_path = paths[i]
    last_part = tmp_path.split("/")[-1]
    splits = last_part.split("_")
    splits[3] = str(round(float(splits[3]), 2))
    splits[5] = str(round(float(splits[5]), 2))
    new_last_part = "_".join(splits)
    new_path = Path(tmp_path).parent / new_last_part

    os.rename(tmp_path, new_path)
# Out:
# 100%|██████████| 40400/40400 [00:00<00:00, 76139.39it/s]

# %%
# prep data for ambiguity
col_names1 = [f"ambi{i}" for i in range(5)]
labels1 = ["0", "1+", "2-", "2+", "3+"]
heights1 = plot_utils.agg_heights_v2(
        root, cv, r_min, r_max, alphas, 
        plot_utils.agg_patch_average_ambi_ihc,
        [f"ambi{i}" for i in range(5)]
    )

col_names2 = [f"ambi{i}" for i in range(2)]
labels2 = ["Neg", "Pos"]
heights2 = plot_utils.agg_heights_v2(
        root, cv, r_min, r_max, alphas, 
        plot_utils.agg_patch_average_ambi_her2,
        col_names2
    )

col_names3 = [f"ambi{i}" for i in range(5)]
labels3 = ["0", "1+", "2-", "2+", "3+"]
heights3 = plot_utils_case.agg_heights_v2(
        root, cv, r_min, r_max, alphas, 
        plot_utils_case.agg_case_average_ambi_ihc,
        col_names3
    )

col_names4 = [f"ambi{i}" for i in range(2)]
labels4 = ["Neg", "Pos"]
heights4 = plot_utils_case.agg_heights_v2(
        root, cv, r_min, r_max, alphas, 
        plot_utils_case.agg_case_average_ambi_her2,
        col_names2
    )
# Out:
# /home/surayuth/her2/.venv/lib/python3.12/site-packages/scipy/stats/_resampling.py:149: RuntimeWarning: invalid value encountered in scalar divide
#   a_hat = 1/6 * sum(nums) / sum(dens)**(3/2)
# /home/surayuth/her2/analysis/utils/plot_utils_case.py:325: DegenerateDataWarning: The BCa confidence interval cannot be calculated. This problem is known to occur when the distribution is degenerate or the statistic is np.min.
#   bi = bootstrap((arr_stats)[:,i].reshape(1,-1), statistic=np.mean)

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12), gridspec_kw={'wspace': 0.15, 'hspace': 0.25})

colors = ["#00629B", "#009CA6", "#00B5E2", "#FFA300", "#BA0C2F"]
for i, col in enumerate(col_names1):
    lower_error = heights1[col]["err_min"]
    upper_error = heights1[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[0, 0].errorbar(
        alphas, 
        heights1[col]["mean"], 
        yerr=asymmetric_error, fmt="-", 
        color=colors[i],
        label=labels1[i], capsize=5
    )
axs[0, 0].legend(frameon=False, fontsize=13)
axs[0, 0].set_xticks(
    ticks=[n for n in alphas], 
    labels=[format(round(n, 2), ".2f") for n in alphas],
    fontsize=13
)
axs[0, 0].set_yticks(
    ticks=np.arange(0, 90+10, 10),
    labels=np.arange(0, 90+10, 10),
    fontsize=13
)
axs[0, 0].set_ylim([-3, 93])
axs[0, 0].set_ylabel("Percentage (%)", fontsize=13)
axs[0, 0].set_title("Patch-Level by IHC Score", fontsize=13)
axs[0, 0].set_xlabel("Significant level", fontsize=13)
axs[0, 0].spines['top'].set_visible(False)
axs[0, 0].spines['right'].set_visible(False)

######################################################

colors = ["#00629B", "#BA0C2F"]                                                                                                 
for i, col in enumerate(col_names2):
    lower_error = heights2[col]["err_min"]
    upper_error = heights2[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[0, 1].errorbar(
        alphas, 
        heights2[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        color=colors[i],
        label=labels2[i], capsize=5
    )
axs[0, 1].legend(frameon=False, fontsize=13)
axs[0, 1].set_xticks(
    ticks=[n for n in alphas], 
    labels=[format(round(n, 2), ".2f") for n in alphas],
    fontsize=13
)
axs[0, 1].set_yticks(
    ticks=np.arange(0, 90+10, 10),
    labels=np.arange(0, 90+10, 10),
    fontsize=13
)
axs[0, 1].set_ylim([-3, 93])
axs[0, 1].set_ylabel("Percentage (%)", fontsize=13)
axs[0, 1].set_title("Patch-level by HER2 status", fontsize=13)
axs[0, 1].set_xlabel("Significant level", fontsize=13)
axs[0, 1].spines['top'].set_visible(False)
axs[0, 1].spines['right'].set_visible(False)

######################################################

colors = ["#00629B", "#009CA6", "#00B5E2", "#FFA300", "#BA0C2F"]
for i, col in enumerate(col_names3):
    lower_error = heights3[col]["err_min"]
    upper_error = heights3[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[1, 0].errorbar(
        alphas, 
        heights3[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        color=colors[i],
        label=labels3[i], capsize=5
    )
axs[1, 0].legend(frameon=False, fontsize=13)
axs[1, 0].set_xticks(
    ticks=[n for n in alphas], 
    labels=[format(round(n, 2), ".2f") for n in alphas],
    fontsize=13
)
axs[1, 0].set_yticks(
    ticks=np.arange(0, 90+10, 10),
    labels=np.arange(0, 90+10, 10),
    fontsize=13
)
axs[1, 0].set_ylim([-3, 93])
axs[1, 0].set_ylabel("Percentage (%)", fontsize=13)
axs[1, 0].set_title("Case-level by IHC score", fontsize=13)
axs[1, 0].set_xlabel("Significant level", fontsize=13)
axs[1, 0].spines['top'].set_visible(False)
axs[1, 0].spines['right'].set_visible(False)

# ######################################################

colors = ["#00629B", "#BA0C2F"]
for i, col in enumerate(col_names4):
    lower_error = heights4[col]["err_min"]
    upper_error = heights4[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[1, 1].errorbar(
        alphas, 
        heights4[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        color=colors[i],
        label=labels4[i], capsize=5
    )
axs[1, 1].legend(frameon=False, fontsize=13)
axs[1, 1].set_xticks(
    ticks=[n for n in alphas], 
    labels=[format(round(n, 2), ".2f") for n in alphas],
    fontsize=13
)
axs[1, 1].set_yticks(
    ticks=np.arange(0, 90+10, 10),
    labels=np.arange(0, 90+10, 10),
    fontsize=13
)
axs[1, 1].set_ylim([-3, 93])
axs[1, 1].set_ylabel("Percentage (%)", fontsize=13)
axs[1, 1].set_title("Case-level by HER2 status", fontsize=13)
axs[1, 1].set_xlabel("Significant level", fontsize=13)
axs[1, 1].spines['top'].set_visible(False)
axs[1, 1].spines['right'].set_visible(False)

# fig.suptitle("Ambiguity at Different Significant Levels", y=0.94, fontsize=16, weight="bold")
#fig.tight_layout()
fig.savefig("figs/tmp_ambiguity.png", dpi=300, bbox_inches="tight")

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 12))

col_names1 = [f"cover{i}" for i in range(5)]
labels1 = ["0", "1+", "2-", "2+", "3+"]

heights1 = plot_utils.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils.agg_patch_coverage_ihc,
        col_names1
    )

for i, col in enumerate(col_names1):
    lower_error = heights1[col]["err_min"]
    upper_error = heights1[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[0, 1].errorbar(
        alphas, 
        heights1[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        label=labels1[i], capsize=5
    )
axs[0, 1].legend()
axs[0, 1].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[0, 1].set_ylabel("Percentage")
axs[0, 1].set_title("Patch-level IHC score")
axs[0, 1].set_xlabel("Significant level")

######################################################

col_names2 = [f"cover{i}" for i in range(2)]
labels2 = ["Neg", "Pos"]

heights2 = plot_utils.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils.agg_patch_coverage_her2,
        col_names2
    )

for i, col in enumerate(col_names2):
    lower_error = heights2[col]["err_min"]
    upper_error = heights2[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[0, 0].errorbar(
        alphas, 
        heights2[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        label=labels2[i], capsize=5
    )

axs[0, 0].plot(
    np.array(alphas),
    (1 - np.array(alphas)) * 100,
    linestyle="--",
    c="k",
    label="theory"
)
axs[0, 0].legend()
axs[0, 0].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[0, 0].set_title("Patch-level HER2 status")
axs[0, 0].set_ylabel("Percentage")
axs[0, 0].set_xlabel("Significant level")

######################################################

col_names1 = [f"cover{i}" for i in range(5)]
labels1 = ["0", "1+", "2-", "2+", "3+"]

heights1 = plot_utils_case.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils_case.agg_case_coverage_ihc,
        col_names1
    )

for i, col in enumerate(col_names1):
    lower_error = heights1[col]["err_min"]
    upper_error = heights1[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[1, 1].errorbar(
        alphas, 
        heights1[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        label=labels1[i], capsize=5
    )
axs[1, 1].legend()
axs[1, 1].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[1, 1].set_ylabel("Percentage")
axs[1, 1].set_title("Case-level IHC score")
axs[1, 1].set_xlabel("Significant level")


######################################################

col_names2 = [f"cover{i}" for i in range(2)]
labels2 = ["Neg", "Pos"]

heights2 = plot_utils_case.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils_case.agg_case_coverage_her2,
        col_names2
    )

for i, col in enumerate(col_names2):
    lower_error = heights2[col]["err_min"]
    upper_error = heights2[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[1, 0].errorbar(
        alphas, 
        heights2[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        label=labels2[i], capsize=5
    )

axs[1, 0].plot(
    np.array(alphas),
    (1 - np.array(alphas)) * 100,
    linestyle="--",
    c="k",
    label="theory"
)
axs[1, 0].legend()
axs[1, 0].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[1, 0].set_title("Case-level HER2 status")
axs[1, 0].set_ylabel("Percentage")
axs[1, 0].set_xlabel("Significant level")

fig.suptitle("Coverage")
fig.tight_layout()
fig.savefig("figs/tmp_coverage.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[78], line 6
#       3 col_names1 = [f"cover{i}" for i in range(5)]
#       4 labels1 = ["0", "1+", "2-", "2+", "3+"]
# ----> 6 heights1 = plot_utils.agg_heights(
#       7         root, cv, r_min, r_max, alphas,
#       8         plot_utils.agg_patch_coverage_ihc,
#       9         col_names1
#      10     )
#      12 for i, col in enumerate(col_names1):
#      13     lower_error = heights1[col]["err_min"]
#
# File ~/her2/analysis/utils/plot_utils.py:139, in agg_heights(root, cv, r_min, r_max, alphas, agg_func, col_names)
#     136 for alpha in alphas:
#     137     file_path = root / f"{r}_{f}" / f"{r}_{f}_{alpha}_result.csv"
# --> 139     df = pl.read_csv(file_path)
#     140     values = agg_func(df)
#     142     row = [r, alpha] + values
#
# File ~/her2/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:91, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      86 @wraps(function)
#      87 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      88     _rename_keyword_argument(
#      89         old_name, new_name, kwargs, function.__qualname__, version
#      90     )
# ---> 91     return function(*args, **kwargs)
#
# File ~/her2/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:91, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      86 @wraps(function)
#      87 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      88     _rename_keyword_argument(
#      89         old_name, new_name, kwargs, function.__qualname__, version
#      90     )
# ---> 91     return function(*args, **kwargs)
#
# File ~/her2/.venv/lib/python3.12/site-packages/polars/_utils/deprecation.py:91, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      86 @wraps(function)
#      87 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      88     _rename_keyword_argument(
#      89         old_name, new_name, kwargs, function.__qualname__, version
#      90     )
# ---> 91     return function(*args, **kwargs)
#
# File ~/her2/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:496, in read_csv(source, has_header, columns, new_columns, separator, comment_prefix, quote_char, skip_rows, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, use_pyarrow, storage_options, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     488 else:
#     489     with prepare_file_arg(
#     490         source,
#     491         encoding=encoding,
#    (...)
#     494         storage_options=storage_options,
#     495     ) as data:
# --> 496         df = _read_csv_impl(
#     497             data,
#     498             has_header=has_header,
#     499             columns=columns if columns else projection,
#     500             separator=separator,
#     501             comment_prefix=comment_prefix,
#     502             quote_char=quote_char,
#     503             skip_rows=skip_rows,
#     504             schema_overrides=schema_overrides,
#     505             schema=schema,
#     506             null_values=null_values,
#     507             missing_utf8_is_empty_string=missing_utf8_is_empty_string,
#     508             ignore_errors=ignore_errors,
#     509             try_parse_dates=try_parse_dates,
#     510             n_threads=n_threads,
#     511             infer_schema_length=infer_schema_length,
#     512             batch_size=batch_size,
#     513             n_rows=n_rows,
#     514             encoding=encoding if encoding == "utf8-lossy" else "utf8",
#     515             low_memory=low_memory,
#     516             rechunk=rechunk,
#     517             skip_rows_after_header=skip_rows_after_header,
#     518             row_index_name=row_index_name,
#     519             row_index_offset=row_index_offset,
#     520             sample_size=sample_size,
#     521             eol_char=eol_char,
#     522             raise_if_empty=raise_if_empty,
#     523             truncate_ragged_lines=truncate_ragged_lines,
#     524             decimal_comma=decimal_comma,
#     525             glob=glob,
#     526         )
#     528 if new_columns:
#     529     return _update_columns(df, new_columns)
#
# File ~/her2/.venv/lib/python3.12/site-packages/polars/io/csv/functions.py:642, in _read_csv_impl(source, has_header, columns, separator, comment_prefix, quote_char, skip_rows, schema, schema_overrides, null_values, missing_utf8_is_empty_string, ignore_errors, try_parse_dates, n_threads, infer_schema_length, batch_size, n_rows, encoding, low_memory, rechunk, skip_rows_after_header, row_index_name, row_index_offset, sample_size, eol_char, raise_if_empty, truncate_ragged_lines, decimal_comma, glob)
#     638         raise ValueError(msg)
#     640 projection, columns = parse_columns_arg(columns)
# --> 642 pydf = PyDataFrame.read_csv(
#     643     source,
#     644     infer_schema_length,
#     645     batch_size,
#     646     has_header,
#     647     ignore_errors,
#     648     n_rows,
#     649     skip_rows,
#     650     projection,
#     651     separator,
#     652     rechunk,
#     653     columns,
#     654     encoding,
#     655     n_threads,
#     656     path,
#     657     dtype_list,
#     658     dtype_slice,
#     659     low_memory,
#     660     comment_prefix,
#     661     quote_char,
#     662     processed_null_values,
#     663     missing_utf8_is_empty_string,
#     664     try_parse_dates,
#     665     skip_rows_after_header,
#     666     parse_row_index_args(row_index_name, row_index_offset),
#     667     sample_size=sample_size,
#     668     eol_char=eol_char,
#     669     raise_if_empty=raise_if_empty,
#     670     truncate_ragged_lines=truncate_ragged_lines,
#     671     decimal_comma=decimal_comma,
#     672     schema=schema,
#     673 )
#     674 return wrap_df(pydf)
#
# FileNotFoundError: No such file or directory (os error 2): ...min_0.02_alpha_max_0.2_step_alpha_0.02_dryrun_ Falsealpha0alpha1/0_0/0_0_0.02_result.csv

# %%
fig, axs = plt.subplots(2, 3, figsize=(20, 12))

col_names = ["sensitivity","specificity", "ambi"]

heights = plot_utils.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils.agg_patch_tpr_fpr_ovr,
        col_names
    )

for i, col in enumerate(col_names[:-1]):
    lower_error = heights[col]["err_min"]
    upper_error = heights[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[0, 0].errorbar(
        alphas, 
        heights[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        label=col, capsize=5
    )

axs[0, 0].set_xlabel("Significant level")
axs[0, 0].set_ylabel("Percentage")
axs[0, 0].legend()
axs[0, 0].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[0, 0].set_title("Patch-level performances overall")

######################################################

col_names = ["sensitivity","specificity", "ambi"]

heights = plot_utils.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils.agg_patch_tpr_fpr,
        col_names
    )

for i, col in enumerate(col_names[:-1]):
    lower_error = heights[col]["err_min"]
    upper_error = heights[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[0, 1].errorbar(
        alphas, 
        heights[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        label=col, capsize=5
    )

axs[0, 1].set_xlabel("Significant level")
axs[0, 1].set_ylabel("Percentage")
axs[0, 1].legend()
axs[0, 1].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[0, 1].set_title("Patch-level performances for 2+ nonambigious cases")

######################################################

col_names = ["sensitivity","specificity", "ambi"]

heights = plot_utils_case.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils_case.agg_case_tpr_fpr_ovr,
        col_names
    )

for i, col in enumerate(col_names[:-1]):
    lower_error = heights[col]["err_min"]
    upper_error = heights[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[1, 0].errorbar(
        alphas, 
        heights[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        label=col, capsize=5
    )

axs[1, 0].set_xlabel("Significant level")
axs[1, 0].set_ylabel("Percentage")
axs[1, 0].legend()
axs[1, 0].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[1, 0].set_title("Case-level performances overall")

######################################################

col_names = ["sensitivity","specificity", "ambi"]

heights = plot_utils_case.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils_case.agg_case_tpr_fpr,
        col_names
    )

for i, col in enumerate(col_names[:-1]):
    lower_error = heights[col]["err_min"]
    upper_error = heights[col]["err_max"]
    asymmetric_error = [lower_error, upper_error]
    axs[1, 1].errorbar(
        alphas, 
        heights[col]["mean"], 
        yerr=asymmetric_error, fmt='-', 
        label=col, capsize=5
    )

axs[1, 1].set_xlabel("Significant level")
axs[1, 1].set_ylabel("Percentage")
axs[1, 1].legend()
axs[1, 1].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[1, 1].set_title("Case-level performances for 2+ nonambigious cases")

######################################################

col_names = ["ambi", "neg", "pos"]

heights = plot_utils.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils.agg_patch_final_pred,
        col_names
    )

for i, col in enumerate(col_names):
    lower_error = np.array(heights[col]["err_min"]) / 100
    upper_error = np.array(heights[col]["err_max"]) / 100
    asymmetric_error = [lower_error, upper_error]
    axs[0, 2].errorbar(
        alphas, 
        np.array(heights[col]["mean"]) / 100, 
        yerr=asymmetric_error, fmt='-', 
        label=col, capsize=5
    )
axs[0, 2].legend()

axs[0, 2].set_xlabel("Significant level")
axs[0, 2].set_ylabel("No. of images")
axs[0, 2].legend()
axs[0, 2].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[0, 2].set_title("Number of final preds (2+ only)")

######################################################


col_names = ["ambi", "neg", "pos"]

heights = plot_utils_case.agg_heights(
        root, cv, r_min, r_max, alphas, 
        plot_utils_case.agg_case_final_pred,
        col_names
    )

for i, col in enumerate(col_names):
    lower_error = np.array(heights[col]["err_min"]) / 100
    upper_error = np.array(heights[col]["err_max"]) / 100
    asymmetric_error = [lower_error, upper_error]
    axs[1, 2].errorbar(
        alphas, 
        np.array(heights[col]["mean"]) / 100, 
        yerr=asymmetric_error, fmt='-', 
        label=col, capsize=5
    )
axs[1, 2].legend()

axs[1, 2].set_xlabel("Significant level")
axs[1, 2].set_ylabel("No. of cases")
axs[1, 2].legend()
axs[1, 2].set_xticks(
    ticks=[0.01, 0.05, 0.1, 0.15, 0.2], 
    labels=["0.01", "0.05", "0.10", "0.15", "0.20"]
)
axs[1, 2].set_title("Number of final preds (2+ only)")


# One possible reason of increasing specificity in the case-level of 2+ case is that 
# the cases that are likely to misclassify are pushed into the "ambigious" cases
# which means we are left with only the "easy" case.

fig.tight_layout()
fig.savefig("figs/tmp_performance.png")
